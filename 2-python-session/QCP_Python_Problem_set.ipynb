# %% [markdown]
# ## Exercise 1: List Analysis Function - Conditional Aggregation
#
# **Focus:** Lists, Loops, Conditionals
#
# **Task:**
# 1.  Define a Python function called `analyze_list_properties(numbers)` that takes one argument: a list of integers (`numbers`).
# 2.  Inside the `analyze_list_properties` function:
#     *   Initialize three counters: `even_count`, `odd_count`, `positive_sum`.
#     *   Initialize `largest_negative` to `None` (or a very small number).
#     *   Use a `for` loop to iterate through each `num` in the `numbers` list.
#     *   Inside the loop, use `if/elif/else` statements (conditionals):
#         *   If `num` is even, increment `even_count`.
#         *   If `num` is odd, increment `odd_count`.
#         *   If `num` is positive, add it to `positive_sum`.
#         *   If `num` is negative, update `largest_negative` if `num` is greater than the current `largest_negative` (or if `largest_negative` is `None`).
#     *   Return a dictionary containing `{'even_count': ..., 'odd_count': ..., 'positive_sum': ..., 'largest_negative': ...}`.
# 3.  Create a sample list of integers, including positive, negative, even, and odd numbers (e.g., `[1, -2, 3, 4, -5, 6, -7, 8, 0, 9]`).
# 4.  Call your `analyze_list_properties` function with this sample list.
# 5.  Print the returned dictionary in a clear, readable format.
#
# _Hint: Remember to handle the case where there are no negative numbers when determining `largest_negative`._

# %%
# Write your solution for Exercise 1 here

# %% [markdown]
# ---

# %% [markdown]
# ## Exercise 2: Student Grade Processor Function
#
# **Focus:** Lists, Loops, Conditionals (Nested structures)
#
# **Task:**
# 1.  Define a Python function called `process_student_data(student_records)` that takes one argument: a list of dictionaries (`student_records`). Each dictionary represents a student with keys `'name'` (string) and `'grades'` (a list of integers).
#     *   Example `student_records`: `[{'name': 'Alice', 'grades': [85, 90, 78]}, {'name': 'Bob', 'grades': [60, 55, 70]}, {'name': 'Charlie', 'grades': [92, 88, 95]}]`
# 2.  Inside the `process_student_data` function:
#     *   Initialize an empty list called `processed_data`.
#     *   Use a `for` loop to iterate through each `student` dictionary in `student_records`.
#     *   Inside this loop, use another `for` loop (or `sum()`) and conditionals to:
#         *   Calculate the `average_grade` for the current student from their `'grades'` list.
#         *   Determine `pass_status` (a string: "Pass" if `average_grade >= 60`, otherwise "Fail").
#     *   Create a new dictionary for the current student containing their `'name'`, `'average_grade'`, and `'pass_status'`.
#     *   Append this new dictionary to the `processed_data` list.
#     *   After the loop, identify the `top_student_name` (the student with the highest `average_grade`). Use another loop and conditionals if necessary.
#     *   Return a tuple: (`processed_data`, `top_student_name`).
# 3.  Create a sample `student_records` list with at least three students.
# 4.  Call your `process_student_data` function with your sample data.
# 5.  Print the `processed_data` list and the `top_student_name` in a well-formatted manner.
#
# _Hint: Ensure your average grade calculation handles empty grade lists gracefully if that's a possibility (though not required by this problem if all students have grades)._

# %%
# Write your solution for Exercise 2 here

# %% [markdown]
# ---

# %% [markdown]
# ## Exercise 3: Matplotlib Function - Categorical Scatter Plot with Highlight
#
# **Focus:** Matplotlib, Lists, Loops, Conditionals
#
# **Task:**
# 1.  Import `matplotlib.pyplot` as `plt` and `numpy` as `np`.
# 2.  Define a Python function called `plot_categorical_data(x_data, y_data, categories, highlight_category=None)` that takes:
#     *   `x_data`: A list of numerical x-coordinates.
#     *   `y_data`: A list of numerical y-coordinates (same length as `x_data`).
#     *   `categories`: A list of strings, where each string corresponds to the category of the `(x_data[i], y_data[i])` point.
#     *   `highlight_category`: (Optional) A string representing a category to plot in a distinct color, overriding its default color.
# 3.  Inside the `plot_categorical_data` function:
#     *   Create a Matplotlib figure and axes.
#     *   Identify all unique categories present in the `categories` list.
#     *   Assign a different default color to each unique category (you can pre-define a list of colors or use a colormap).
#     *   Use a `for` loop and `enumerate` to iterate through `x_data`, `y_data`, and `categories` simultaneously.
#     *   Inside the loop, use conditionals (`if/else`):
#         *   If the current `category` matches `highlight_category`, plot the point with a specific highlight color (e.g., 'red').
#         *   Otherwise, plot the point with its assigned default color for that category.
#         *   Use `plt.scatter()` for plotting each point.
#     *   Add a legend to the plot, ensuring each unique category (and the highlight if used) is represented.
#     *   Add a title (e.g., "Categorical Data Visualization") and axis labels ("X-Values", "Y-Values").
#     *   Display the plot (`plt.show()`).
# 4.  Generate sample data:
#     *   `x_data`: e.g., 20 random numbers between 0 and 10.
#     *   `y_data`: e.g., 20 random numbers between 0 and 10.
#     *   `categories`: e.g., 20 random choices from `['Group A', 'Group B', 'Group C']`.
# 5.  Call your `plot_categorical_data` function twice:
#     *   Once without `highlight_category`.
#     *   Once with `highlight_category` set to one of your chosen categories (e.g., 'Group B').
#
# _Hint: You can use `np.random.rand()` or `np.random.randint()` for data generation. `plt.cm.get_cmap()` can help with getting colors, or you can manually create a dictionary mapping categories to colors._

# %%
# Write your solution for Exercise 3 here
